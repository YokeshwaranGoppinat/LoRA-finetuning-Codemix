# %%
# LoRA Project Colab Runner
# 1) Clone the repo (if needed)
# 2) Install requirements
# 3) Run a small import sanity check

import os

REPO_URL = "https://github.com/YokeshwaranGoppinat/LoRA-finetuning-Codemix.git"
REPO_DIR = "/content/LoRA-finetuning-Codemix"

# Clone the repo only if it doesn't exist
if not os.path.exists(REPO_DIR):
    # !git clone $REPO_URL $REPO_DIR

# Move into the repo directory
# %cd $REPO_DIR

# Install dependencies
# !pip install -q -r requirements.txt

# Sanity check: key imports
import torch
import transformers
import peft

print("✅ Torch version:", torch.__version__)
print("✅ Transformers version:", transformers.__version__)
print("✅ PEFT version:", peft.__version__)

print("\n✅ Environment is ready.")
print("Next step: open and run notebooks/LoRA_trainer.ipynb to reproduce the LoRA experiments.")
# Out:
# Cloning into '/content/LoRA-finetuning-Codemix'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 88.99 KiB | 2.12 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/LoRA-finetuning-Codemix
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.1/123.1 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.4/755.4 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 37.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.7/279.7 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 10.6 MB/s eta 0:00:00
# ...
